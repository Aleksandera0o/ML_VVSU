# %% [markdown]
# <a href="https://colab.research.google.com/github/Aleksandera0o/ML_VVSU/blob/main/lab3/%D0%97%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Задание по практике 3

# %% [markdown]
# ##Обработка пропущенных значений

# %% [markdown]
# Обработайте пропущенные значения:
#
#
# * Удалите пропущенные значения
# * Заполните при помощи медианы, среднего для числовых значений
# * Заполните при помощи моды для категориальных значений
# * Интерполируйте
# Выведите статистку после каждого метода и объясните

# %%
# !pip install scikit-learn

# %%
import pandas as pd

df = pd.read_csv('/content/Global YouTube Statistics.csv', encoding = "ISO-8859-1")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   rank                                     995 non-null    int64
#  1   Youtuber                                 995 non-null    object
#  2   subscribers                              995 non-null    int64
#  3   video views                              995 non-null    float64
#  4   category                                 949 non-null    object
#  5   Title                                    995 non-null    object
#  6   uploads                                  995 non-null    int64
#  7   Country                                  873 non-null    object
#  8   Abbreviation                             873 non-null    object
#  9   channel_type                             965 non-null    object
# ...

# %%
df
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 1       2              YouTube Movies    170000000  0.000000e+00
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aï¿     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 992   993                       Panda     12300000  2.214684e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#              category                       Title  uploads         Country  \
# 0               Music                    T-Series    20082           India
# ...

# %%
df_clear=df.dropna()
df_clear
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# 8       9                 Like Nastya    106000000  9.047906e+10
# ..    ...                         ...          ...           ...
# 989   990                   Migos ATL     12400000  6.993406e+09
# 990   991               Natan por Aï¿     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# ...

# %%
#Заполнение при помощи медианы
df_median=df.fillna(df.median())
df_median
# Out:
# <ipython-input-5-c67a0d5dda34>:2: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_median=df.fillna(df.median())
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 1       2              YouTube Movies    170000000  0.000000e+00
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aï¿     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# ...

# %%
#Заполнение при помощи среднего
df_mean=df.fillna(df.mean())
df_mean
# Out:
# <ipython-input-6-81ec3c4521ac>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_mean=df.fillna(df.mean())
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 1       2              YouTube Movies    170000000  0.000000e+00
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aï¿     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# ...

# %%
df_mode = pd.DataFrame(columns = df.columns)
for col in df.columns:
  df_mode[col] = df[col].fillna(df[col].mode()[0])
df_mode
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 1       2              YouTube Movies    170000000  0.000000e+00
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aï¿     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 992   993                       Panda     12300000  2.214684e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#              category                       Title  uploads         Country  \
# 0               Music                    T-Series    20082           India
# ...

# %%
#Заполнение при помощи интерполяции
df_inter = df.interpolate(method ='linear')
df_inter
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 1       2              YouTube Movies    170000000  0.000000e+00
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aï¿     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 992   993                       Panda     12300000  2.214684e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#              category                       Title  uploads         Country  \
# 0               Music                    T-Series    20082           India
# ...

# %% [markdown]
# ##Поиск выбросов и аномалий

# %% [markdown]
# **Те, кто выполняет задания со * делают поиск выбросов с помощью написанного ранее класса**
#
# Найти выбросы по числовой переменной (использовать метод основанный на среднем и на межквартильном размахе). Объясните результат
#
# Вывести статистику с выбросами и без. Сравните и объясните результат

# %%
import math
from statistics import median, mean
import pandas as pd
import numpy as np
import scipy.stats as stats
from sklearn.ensemble import IsolationForest

class Outline:
  def __init__(self, df):
    self.df = df.copy()

  def drop_by_shovene(self, column):
    n = self.df[column].count()
    cnt=0
    result = []
    for elem in self.df[column]:
        mean = self.df[column].mean()
        std = self.df[column].std()
        if math.erfc((abs(elem - mean)) / std) < 1 / (2 * n):
            n -= 1
            result.append(cnt)
        cnt+=1
    if len(result)==1:
      self.df = self.df.drop(index = result[0])
    elif len(result)>1:
      self.df = self.df.drop(index = result)
    return self.df

  def drop_by_quantile(self, column):
      q1 = self.df[column].quantile(0.25)
      q3 = self.df[column].quantile(0.75)
      minimum = q1-1.5*(q3-q1)
      maximum = q3+1.5*(q3-q1)
      return self.df[(self.df[column] >= minimum) & (self.df[column] <= maximum)]

  def delete_outline_by_mean(self, column):
    mean_data = mean(self.df[column])
    maximum = mean_data * 2
    result = []
    cnt = 0
    for item in self.df[column]:
      if abs(item - mean_data) > maximum:
        result.append(cnt)
        cnt+=1
    if len(result)==1:
      self.df = self.df.drop(index = result[0])
    elif len(result)>1:
      self.df = self.df.drop(index = result)
    return self.df

  def drop_by_mean_std(self,column):
      result = []
      cnt =0
      print(self.df[column].mean(),self.df[column].std())
      for elem in self.df[column]:
        mean = self.df[column].mean()
        std = self.df[column].std()
        if abs((elem-mean)/std) >3 :
          result.append(cnt)
        cnt+=1
      if len(result)==1:
        self.df = self.df.drop(index = result[0])
      elif len(result)>1:
        self.df = self.df.drop(index = result)
      return self.df

  def drop_by_two_var(self):
      iso_forest = IsolationForest(n_estimators=10)
      iso_forest.fit(self.df)
      return self.df[iso_forest.predict(self.df)!=-1]

# %%
#Методом среднего
test1 = Outline(df)
test1_df_drop = test1.delete_outline_by_mean('subscribers')
test1_df_drop
# Out:
#      rank                                     Youtuber  subscribers  \
# 22     23  Pinkfong Baby Shark - Kids' Songs & Stories     68200000
# 23     24                              Canal KondZilla     66500000
# 24     25        ChuChu TV Nursery Rhymes & Kids Songs     65900000
# 25     26                         Shemaroo Filmi Gaane     65600000
# 26     27                                    Colors TV     64600000
# ..    ...                                          ...          ...
# 990   991                                Natan por Aï¿     12300000
# 991   992                     Free Fire India Official     12300000
# 992   993                                        Panda     12300000
# 993   994                                  RobTopGames     12300000
# 994   995                                 Make Joke Of     12300000
#
#       video views        category  \
# 22   3.884323e+10       Education
# 23   3.677559e+10           Music
# 24   4.575785e+10       Education
# ...

# %%
#При помощи межквартильного размаха
test1_df_quantile=test1.drop_by_quantile('subscribers')
test1_df_quantile
# Out:
#      rank                  Youtuber  subscribers   video views  \
# 87     88             One Direction     38200000  1.359890e+10
# 88     89              TheEllenShow     38200000  2.275658e+10
# 89     90                  Sony PAL     38200000  2.851934e+10
# 90     91              Daddy Yankee     38000000  2.273142e+10
# 91     92             Vlad vï¿½ï¿½ï     37900000  2.351015e+10
# ..    ...                       ...          ...           ...
# 990   991             Natan por Aï¿     12300000  9.029610e+09
# 991   992  Free Fire India Official     12300000  1.674410e+09
# 992   993                     Panda     12300000  2.214684e+09
# 993   994               RobTopGames     12300000  3.741235e+08
# 994   995              Make Joke Of     12300000  2.129774e+09
#
#            category                     Title  uploads         Country  \
# 87            Music                 21 Savage       11   United States
# ...

# %%
#Статистика и объяснение
df.describe()
# Out:
#             rank   subscribers   video views        uploads  video_views_rank  \
# count  995.00000  9.950000e+02  9.950000e+02     995.000000      9.940000e+02
# mean   498.00000  2.298241e+07  1.103954e+10    9187.125628      5.542489e+05
# std    287.37606  1.752611e+07  1.411084e+10   34151.352254      1.362782e+06
# min      1.00000  1.230000e+07  0.000000e+00       0.000000      1.000000e+00
# 25%    249.50000  1.450000e+07  4.288145e+09     194.500000      3.230000e+02
# 50%    498.00000  1.770000e+07  7.760820e+09     729.000000      9.155000e+02
# 75%    746.50000  2.460000e+07  1.355470e+10    2667.500000      3.584500e+03
# max    995.00000  2.450000e+08  2.280000e+11  301308.000000      4.057944e+06
#
#        country_rank  channel_type_rank  video_views_for_the_last_30_days  \
# count    879.000000         962.000000                      9.390000e+02
# mean     386.053470         745.719335                      1.756103e+08
# ...

# %%
test1_df_drop.describe()
# Out:
#              rank   subscribers   video views        uploads  \
# count  973.000000  9.730000e+02  9.730000e+02     973.000000
# mean   509.000000  2.099538e+07  9.921905e+09    8954.168551
# std    281.025206  9.683738e+06  8.409462e+09   34013.207411
# min     23.000000  1.230000e+07  0.000000e+00       0.000000
# 25%    266.000000  1.450000e+07  4.266957e+09     195.000000
# 50%    509.000000  1.760000e+07  7.634430e+09     724.000000
# 75%    752.000000  2.400000e+07  1.312465e+10    2572.000000
# max    995.000000  6.820000e+07  6.151091e+10  301308.000000
#
#        video_views_rank  country_rank  channel_type_rank  \
# count      9.720000e+02    860.000000         941.000000
# mean       5.419123e+05    372.745349         735.430393
# std        1.348830e+06   1193.498150        1928.772394
# min        1.000000e+01      1.000000           1.000000
# 25%        3.435000e+02     12.000000          28.000000
# 50%        9.455000e+02     52.500000          67.000000
# ...

# %%
test1_df_quantile.describe()
# Out:
#             rank   subscribers   video views        uploads  video_views_rank  \
# count  908.00000  9.080000e+02  9.080000e+02     908.000000      9.070000e+02
# mean   541.50000  1.905341e+07  8.790016e+09    8238.639868      5.322527e+05
# std    262.26132  6.246839e+06  6.579738e+09   32188.054991      1.337300e+06
# min     88.00000  1.230000e+07  0.000000e+00       0.000000      1.400000e+01
# 25%    314.75000  1.437500e+07  4.048378e+09     196.750000      3.835000e+02
# 50%    541.50000  1.690000e+07  7.209981e+09     719.000000      1.029000e+03
# 75%    768.25000  2.242500e+07  1.169762e+10    2385.500000      3.748000e+03
# max    995.00000  3.820000e+07  5.610609e+10  301308.000000      4.057944e+06
#
#        country_rank  channel_type_rank  video_views_for_the_last_30_days  \
# count    803.000000         879.000000                      8.560000e+02
# mean     381.478207         729.235495                      1.536962e+08
# ...

# %% [markdown]
# **Объяснения**
# При удалении аномалий у нас уменшилось кол-во просмотров так как каналы у которых много подписчиков(они аномальны) у них много просмотров и из-за этого при удалении средние уменшились

# %% [markdown]
# ##Дубликаты

# %% [markdown]
# Проверьте датафрейм на дубликаты и удалите их, если дублей нет - создайте.

# %%
#Проверка на дубли
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [rank, Youtuber, subscribers, video views, category, Title, uploads, Country, Abbreviation, channel_type, video_views_rank, country_rank, channel_type_rank, video_views_for_the_last_30_days, lowest_monthly_earnings, highest_monthly_earnings, lowest_yearly_earnings, highest_yearly_earnings, subscribers_for_last_30_days, created_year, created_month, created_date, Gross tertiary education enrollment (%), Population, Unemployment rate, Urban_population, Latitude, Longitude]
# Index: []
#
# [0 rows x 28 columns]

# %%
df.loc[len(df)] = df.loc[0]

# %%
df[df.duplicated()]
# Out:
#      rank  Youtuber  subscribers   video views category     Title  uploads  \
# 995     1  T-Series    245000000  2.280000e+11    Music  T-Series    20082
# 996     1  T-Series    245000000  2.280000e+11    Music  T-Series    20082
# 997     1  T-Series    245000000  2.280000e+11    Music  T-Series    20082
# 998     1  T-Series    245000000  2.280000e+11    Music  T-Series    20082
# 999     1  T-Series    245000000  2.280000e+11    Music  T-Series    20082
#
#     Country Abbreviation channel_type  ...  subscribers_for_last_30_days  \
# 995   India           IN        Music  ...                     2000000.0
# 996   India           IN        Music  ...                     2000000.0
# 997   India           IN        Music  ...                     2000000.0
# 998   India           IN        Music  ...                     2000000.0
# 999   India           IN        Music  ...                     2000000.0
#
#      created_year  created_month  created_date  \
# ...

# %%
#Удаление дублей
df=df.drop_duplicates()
df
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 1       2              YouTube Movies    170000000  0.000000e+00
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aï¿     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 992   993                       Panda     12300000  2.214684e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#              category                       Title  uploads         Country  \
# 0               Music                    T-Series    20082           India
# ...

# %% [markdown]
# ## Преобразование признаков

# %% [markdown]
# Масштабируйте числовые признаки через MinMaxScaler, StandardScaler

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# Creating instances
min_max_scaler = MinMaxScaler()
standard_scaler = StandardScaler()
num_col = df.select_dtypes(include=['float64']).columns
df_minmax_scaled = df.copy()
df_minmax_scaled[num_col] = min_max_scaler.fit_transform(df[num_col])
df_minmax_scaled.subscribers.unique()
# Out:
# array([245000000, 170000000, 166000000, 162000000, 159000000, 119000000,
#        112000000, 111000000, 106000000,  98900000,  96700000,  96000000,
#         93600000,  89800000,  86900000,  83000000,  80100000,  75600000,
#         75000000,  71600000,  71300000,  70500000,  68200000,  66500000,
#         65900000,  65600000,  64600000,  61000000,  59500000,  59300000,
#         58400000,  58000000,  57600000,  57200000,  56900000,  56400000,
#         54600000,  54000000,  53500000,  53300000,  52900000,  52700000,
#         52200000,  48100000,  47900000,  47500000,  47400000,  46800000,
#         46600000,  46300000,  46100000,  45500000,  45200000,  44700000,
#         44600000,  44500000,  44200000,  43700000,  43600000,  43500000,
#         43200000,  42500000,  42400000,  41900000,  41400000,  41300000,
#         40900000,  40600000,  40400000,  40300000,  39700000,  39400000,
#         39200000,  39100000,  39000000,  38900000,  38600000,  38400000,
# ...

# %%
standard_scaler = StandardScaler()
df_standard_scaler = df.copy()
df_standard_scaler[num_col] = standard_scaler.fit_transform(df[num_col])
df_standard_scaler.subscribers.unique()
# Out:
# array([245000000, 170000000, 166000000, 162000000, 159000000, 119000000,
#        112000000, 111000000, 106000000,  98900000,  96700000,  96000000,
#         93600000,  89800000,  86900000,  83000000,  80100000,  75600000,
#         75000000,  71600000,  71300000,  70500000,  68200000,  66500000,
#         65900000,  65600000,  64600000,  61000000,  59500000,  59300000,
#         58400000,  58000000,  57600000,  57200000,  56900000,  56400000,
#         54600000,  54000000,  53500000,  53300000,  52900000,  52700000,
#         52200000,  48100000,  47900000,  47500000,  47400000,  46800000,
#         46600000,  46300000,  46100000,  45500000,  45200000,  44700000,
#         44600000,  44500000,  44200000,  43700000,  43600000,  43500000,
#         43200000,  42500000,  42400000,  41900000,  41400000,  41300000,
#         40900000,  40600000,  40400000,  40300000,  39700000,  39400000,
#         39200000,  39100000,  39000000,  38900000,  38600000,  38400000,
# ...

# %% [markdown]
# Масштабируйте категориальные признаки через OneHotEncoder

# %%
from sklearn.preprocessing import OneHotEncoder
df.category = df.category.astype('category')
df.Country	 = df.Country	.astype('category')
category_col = df.select_dtypes(include=['category']).columns
encoder = OneHotEncoder()
df_cat_encoded = pd.get_dummies(df, columns=category_col, drop_first=True)
encoded_features = encoder.fit_transform(df[category_col])
encoded_columns = encoder.get_feature_names_out(category_col)
encoded_columns
# Out:
# <ipython-input-41-19ea5b9fa359>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.category = df.category.astype('category')
# <ipython-input-41-19ea5b9fa359>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Country	 = df.Country	.astype('category')
# array(['category_Autos & Vehicles', 'category_Comedy',
#        'category_Education', 'category_Entertainment',
#        'category_Film & Animation', 'category_Gaming',
# ...

# %%
df_cat_encoded
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 1       2              YouTube Movies    170000000  0.000000e+00
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aï¿     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 992   993                       Panda     12300000  2.214684e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#                           Title  uploads Abbreviation   channel_type  \
# 0                      T-Series    20082           IN          Music
# ...

# %% [markdown]
# ##Задание для гениев*

# %% [markdown]
# Реализовать расчет корреляции Спирмана

# %% [markdown]
# ###Пример реализации

# %%
import pandas as pd
import numpy as np


def corr_pearson(column_1, column_2):
  cov = np.cov(column_1, column_2)
  return cov/(column_1.std() * column_2.std())

# %%
data = {
    'Рост': [170, 155, 180, 162, 175],
    'Вес': [65, 50, 75, 55, 70]
}
df = pd.DataFrame(data)
df
# Out:
#    Рост  Вес
# 0   170   65
# 1   155   50
# 2   180   75
# 3   162   55
# 4   175   70

# %%
corr_pearson(df["Рост"], df["Вес"])
# Out:
# array([[0.96593129, 0.99674864],
#        [0.99674864, 1.03527033]])
