# %% [markdown]
# <a href="https://colab.research.google.com/github/Aleksandera0o/ML_VVSU/blob/main/lab1/%D0%97%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Задание по практике 1

# %% [markdown]
# ##Загрузка датасета
# В файле classification datasets расположены ссылки на датасеты. Выберите один в соответствии со своим вариантом, скачайте и прочитайте файл
#
# **Не забудьте загрузить нужные библиотеки**
#
# Например: pip3 install pandas

# %%
import pandas as pd

# %% [markdown]
# Нет ответа не следующие вопросы: "Какие средние значения в каждой числовой колонке вашего датасета?
# Минимальные и максимальные значения в каждой числовой колонке вашего датасета
# "
# Типизировать надо все колонки
# Нет ответа на вопрос: "Какие признаки вы можете выделить в своем датасете (категориальные, числовые и др., минимум 3 разных, помните что можно также выделить признаки более точно, например числовые - порядковые, количественные и т.д.)?"

# %%
df = pd.read_csv('/content/Global_YouTube_Statistics.csv', encoding = "ISO-8859-1")
df
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 1       2              YouTube Movies    170000000  0.000000e+00
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aï¿     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 992   993                       Panda     12300000  2.214684e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#              category                       Title  uploads         Country  \
# 0               Music                    T-Series    20082           India
# ...

# %% [markdown]
# ##Первое знакомство с датасетом
# В следующих ячейках выведите:
#
#
# 1.   Колонки датасета
# 2.   Первые 5 значений
# 3.   Последние 5 значений
# 4.   Статистику по числовым колонкам

# %%
df.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'Title',
#        'uploads', 'Country', 'Abbreviation', 'channel_type',
#        'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'lowest_monthly_earnings',
#        'highest_monthly_earnings', 'lowest_yearly_earnings',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days',
#        'created_year', 'created_month', 'created_date',
#        'Gross tertiary education enrollment (%)', 'Population',
#        'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
df.head(5)
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 1     2              YouTube Movies    170000000  0.000000e+00
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4     5                   SET India    159000000  1.480000e+11
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
# 4             Shows                   SET India   116536          India
#
#   Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0           IN          Music  ...                     2000000.0
# ...

# %%
df.tail(5)
# Out:
#      rank                  Youtuber  subscribers   video views  \
# 990   991             Natan por Aï¿     12300000  9.029610e+09
# 991   992  Free Fire India Official     12300000  1.674410e+09
# 992   993                     Panda     12300000  2.214684e+09
# 993   994               RobTopGames     12300000  3.741235e+08
# 994   995              Make Joke Of     12300000  2.129774e+09
#
#            category                     Title  uploads         Country  \
# 990          Sports             Natan por Aï¿     1200          Brazil
# 991  People & Blogs  Free Fire India Official     1500           India
# 992             NaN               HybridPanda     2452  United Kingdom
# 993          Gaming               RobTopGames       39          Sweden
# 994          Comedy              Make Joke Of       62           India
#
#     Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 990           BR  Entertainment  ...                      700000.0
# ...

# %%
df.describe()
# Out:
#             rank   subscribers   video views        uploads  video_views_rank  \
# count  995.00000  9.950000e+02  9.950000e+02     995.000000      9.940000e+02
# mean   498.00000  2.298241e+07  1.103954e+10    9187.125628      5.542489e+05
# std    287.37606  1.752611e+07  1.411084e+10   34151.352254      1.362782e+06
# min      1.00000  1.230000e+07  0.000000e+00       0.000000      1.000000e+00
# 25%    249.50000  1.450000e+07  4.288145e+09     194.500000      3.230000e+02
# 50%    498.00000  1.770000e+07  7.760820e+09     729.000000      9.155000e+02
# 75%    746.50000  2.460000e+07  1.355470e+10    2667.500000      3.584500e+03
# max    995.00000  2.450000e+08  2.280000e+11  301308.000000      4.057944e+06
#
#        country_rank  channel_type_rank  video_views_for_the_last_30_days  \
# count    879.000000         962.000000                      9.390000e+02
# mean     386.053470         745.719335                      1.756103e+08
# ...

# %% [markdown]
# **Ответьте на следующие вопросы:**
#
#
# 1.   Какие средние значения в каждой числовой колонке вашего датасета?
# 2.   Минимальные и максимальные значения в каждой числовой колонке вашего датасета

# %% [markdown]
# 1.   **Ответ 1.** Средние значения - 498.00000	2.298241e+07	1.103954e+10	9187.125628	5.542489e+05	386.053470	745.719335	1.756103e+08	36886.148281	5.898078e+05	...	7.081814e+06	3.490791e+05	2012.630303	15.746465	63.627752	4.303873e+08	9.279278	2.242150e+08	26.632783	-14.128146 по порядку как в таблице describe
# 2.   **Ответ 2.** MIN = 1.00000	1.230000e+07	0.000000e+00	0.000000	1.000000e+00	1.000000	1.000000	1.000000e+00	0.000000	0.000000e+00	...	0.000000e+00	1.000000e+00	1970.000000	1.000000	7.600000	2.025060e+05	0.750000	3.558800e+04	-38.416097	-172.104629
# MAX =995.00000	2.450000e+08	2.280000e+11	301308.000000	4.057944e+06	7741.000000	7741.000000	6.589000e+09	850900.000000	1.360000e+07	...	1.634000e+08	8.000000e+06	2022.000000	31.000000	113.100000	1.397715e+09	14.720000	8.429340e+08	61.924110	138.252924

# %% [markdown]
# ##Типизация
# Присвойте соответствующим колонкам один из типов (category, float, int)

# %%
df['category']=df['category'].astype('category')
df['subscribers']=df['subscribers'].astype(int)
df['Unemployment rate']=df['Unemployment rate'].astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   rank                                     995 non-null    int64
#  1   Youtuber                                 995 non-null    object
#  2   subscribers                              995 non-null    int64
#  3   video views                              995 non-null    float64
#  4   category                                 949 non-null    category
#  5   Title                                    995 non-null    object
#  6   uploads                                  995 non-null    int64
#  7   Country                                  873 non-null    object
#  8   Abbreviation                             873 non-null    object
#  9   channel_type                             965 non-null    object
# ...

# %% [markdown]
# Какие признаки вы можете выделить в своем датасете (категориальные, числовые и др., **минимум 3 разных**, помните что можно также выделить признаки более точно, например числовые - порядковые, количественные и т.д.)?
# Категориальные - Категории,страна
# числовые - просмотры, подписчики
# порядковые -ранк, video_view_rank

# %% [markdown]
# ##Фильтрация
# Офильтруйте 3 колонки вашего датасета и выведите результат

# %%
df.loc[df['rank']<500]
# Out:
#      rank                          Youtuber  subscribers   video views  \
# 0       1                          T-Series    245000000  2.280000e+11
# 1       2                    YouTube Movies    170000000  0.000000e+00
# 2       3                           MrBeast    166000000  2.836884e+10
# 3       4        Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                         SET India    159000000  1.480000e+11
# ..    ...                               ...          ...           ...
# 494   495  MSA previously My Story Animated     17800000  8.588705e+09
# 495   496                  ýýýýýýýýý KIMPRO     17700000  1.920670e+10
# 496   497                  Jane ASMR ï¿½ï¿½     17700000  7.387622e+09
# 497   498                  ArianaGrandeVevo     17700000  2.011554e+10
# 498   499                      jaanvi patel     17700000  7.912733e+09
#
#              category                             Title  uploads  \
# ...

# %%
df.loc[df['category']=='Shows']
# Out:
#      rank                                 Youtuber  subscribers   video views  \
# 4       5                                SET India    159000000  1.480000e+11
# 15     16                                 Sony SAB     83000000  1.010000e+11
# 26     27                                Colors TV     64600000  6.151091e+10
# 67     68                       Masha and The Bear     42400000  2.451902e+10
# 89     90                                 Sony PAL     38200000  2.851934e+10
# 137   138                                  Mr Bean     32100000  1.060224e+10
# 293   294  Kids TV - Nursery Rhymes And Baby Songs     23100000  1.315187e+10
# 415   416                                Sony AATH     19600000  1.393002e+10
# 440   441                           Masha e o Urso     18900000  8.301731e+09
# 491   492                            MGC Playhouse     17900000  1.617453e+10
# 632   633                     ýýýýýýýý ýý ýýýýýýýý     15500000  8.265130e+09
# ...

# %%
df.loc[df['Country']=='India']
# Out:
#      rank                  Youtuber  subscribers   video views  \
# 0       1                  T-Series    245000000  2.280000e+11
# 4       5                 SET India    159000000  1.480000e+11
# 10     11         Zee Music Company     96700000  5.785629e+10
# 15     16                  Sony SAB     83000000  1.010000e+11
# 21     22                    Zee TV     70500000  7.313905e+10
# ..    ...                       ...          ...           ...
# 980   981                  Zee Kids     12400000  7.683670e+09
# 981   982          Pari's Lifestyle     12400000  7.741765e+09
# 984   985      bharatzkitchen HINDI     12400000  2.315227e+09
# 991   992  Free Fire India Official     12300000  1.674410e+09
# 994   995              Make Joke Of     12300000  2.129774e+09
#
#              category                     Title  uploads Country Abbreviation  \
# 0               Music                  T-Series    20082   India           IN
# ...

# %% [markdown]
# ##Группировка
# Сгруппируйте датасет по какому-либо категориальному признаку и выведите среднее значение численных колонок (см. метод mean в pandas)

# %%
df.groupby('Country').mean()
# Out:
# <ipython-input-25-f9dfe299928b>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Country').mean()
#                             rank   subscribers   video views       uploads  \
# Country
# Afghanistan           378.000000  2.040000e+07  1.339700e+10      0.000000
# Andorra               664.000000  1.510000e+07  2.400038e+09    159.000000
# Argentina             347.000000  2.526923e+07  1.495503e+10   1326.153846
# Australia             482.777778  1.911111e+07  7.682424e+09    797.666667
# Bangladesh            809.000000  1.390000e+07  1.212958e+10      6.000000
# Barbados               70.000000  4.190000e+07  2.247775e+10     84.000000
# Brazil                583.661290  1.970645e+07  7.761435e+09   2712.548387
# ...

# %% [markdown]
# ##Задание для гениев *
# Агрегируйте числовой признак по категориальному признаку с использованием метода **без использования** библиотеки pandas, и вычислите медиану и среднее значение для каждой категории.

# %%
#Агрегация
